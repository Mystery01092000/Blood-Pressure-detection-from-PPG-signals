# %%
#Importing important libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %matplotlib inline

# %%
data = pd.read_csv("DataSet/PPG-BP dataset.csv")

data.head()
# Out:
#    Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0     1           2   Female         45         152          63
# 1     2           3   Female         50         157          50
# 2     3           6   Female         47         150          47
# 3     4           8     Male         45         172          65
# 4     5           9   Female         46         155          65
#
#    Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                            161                              89
# 1                            160                              93
# 2                            101                              71
# 3                            136                              93
# 4                            123                              73
#
#    Heart Rate(b/m)  BMI(kg/m^2)          Hypertension Diabetes  \
# 0               97        27.27  Stage 2 hypertension      NaN
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.shape
# Out:
# (219, 14)

# %%
data.drop('Num.',axis=1 ,inplace=True)

# %%
data.drop('Diabetes',axis=1,inplace=True)
data.drop('cerebral infarction',axis=1,inplace=True)
data.drop('cerebrovascular disease',axis=1,inplace=True)

# %%
data2 = pd.read_excel(r'Dataset\Table1.xlsx')

# %%
data2.head()
# Out:
#    Num.  subject_ID  segment 1  segment 2  Segment 3
# 0     1           2       0.98       0.96       0.92
# 1     2           3       0.69       0.80       0.81
# 2     3           6       0.58       0.59       0.64
# 3     4           8       0.96       0.85       0.87
# 4     5           9       0.65       0.67       0.87

# %%
data2.drop('Num.',axis =1 , inplace=True)

# %%
df =pd.merge(data,data2,on='subject_ID')

# %%
df.head()
# Out:
#    subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0           2   Female         45         152          63
# 1           3   Female         50         157          50
# 2           6   Female         47         150          47
# 3           8     Male         45         172          65
# 4           9   Female         46         155          65
#
#    Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                            161                              89
# 1                            160                              93
# 2                            101                              71
# 3                            136                              93
# 4                            123                              73
#
#    Heart Rate(b/m)  BMI(kg/m^2)          Hypertension  segment 1  segment 2  \
# 0               97        27.27  Stage 2 hypertension       0.98       0.96
# ...

# %%
df.isnull().sum()
# Out:
# subject_ID                        0
# Sex(M/F)                          0
# Age(year)                         0
# Height(cm)                        0
# Weight(kg)                        0
# Systolic Blood Pressure(mmHg)     0
# Diastolic Blood Pressure(mmHg)    0
# Heart Rate(b/m)                   0
# BMI(kg/m^2)                       0
# Hypertension                      0
# segment 1                         0
# segment 2                         0
# Segment 3                         0
# dtype: int64
